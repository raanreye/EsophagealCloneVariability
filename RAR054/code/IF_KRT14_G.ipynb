# %%
# go to the correct directory or change the paths

# %%
# turn into tiffs

# %%
import nd2reader
import tifffile as tiff

# Path to the .nd2 file
nd2_file_path = '/Volumes/RARH_incu/251023_STR_KRT14_G/20231025_191407_905__PlateRARH_K14_G_Well6_ChannelDAPI,A647_Seq0002.nd2'

# Load the .nd2 file
nd2 = nd2reader.ND2Reader(nd2_file_path)

# Extract metadata to find out how many channels there are
# This depends on the nd2reader version; if this doesn't work, consult the specific version's documentation
metadata = nd2.metadata

# Get the number of channels
num_channels = len(metadata['channels'])

# Loop through each channel and save the images
for i in range(num_channels):
    # Assuming we are only dealing with a single frame and single z-level
    # Adjust the code here if you have multiple frames or z-levels
    images = nd2.get_frame_2D(c=i)
    
    # Save the images
    tiff.imwrite(f'channel_{i}.tif', images)

# Close the nd2 file
nd2.close()

# %%
# Crop the colonies

# %%
#KRT14

import tifffile as tiff

# Define your rectangles with coordinates (x, y, width, height)
rectangles = [
    (10048,9630, 10472, 10046),
    (16208,1568,16856,2256),
    (7336,11249,8363,12321),
    (2736,9737,3792,10657),
    (11496,18729,13256,20265),
    (7976,23720,8984,24720),
    (10728,24440,12200,26264),
    (11648,26400,12560,27232),
    (13592,27040,14824,27712),
    (14712,26184,16168,27528),
    (16648,24840,18712,26968),
    (23728,19110,25472,20446),
    (17648,21942,18888,23102),
    (20728,21710,22808,23494),
    (22152,7310,24544,9374),
]

# Function to crop the image based on given coordinates
def crop_image(image, crop_rectangle):
    x, y, width, height = crop_rectangle
    height = height - y
    width = width - x
    return image[y:y+height, x:x+width]

# Crop the rectangles from each channel
for i in range(2):  # Assuming there are two channels as per your original question
    # Load the original .tif file for the channel
    channel_image = tiff.imread(f'well1/channel_{i}.tif')
    
    # Crop each rectangle and save it
    for j, rectangle in enumerate(rectangles):
        cropped_image = crop_image(channel_image, rectangle)
        tiff.imwrite(f'well1/crops/channel_{i}_crop_{j}.tif', cropped_image)

# %%
#KRT14

import tifffile as tiff

# Define your rectangles with coordinates (x, y, width, height)
rectangles = [
    (15072,1296,16272,2568),
    (12288,4584,13224,5472),
    (18456,5280,19368,6528),
    (14448,6000,16584,8016),
    (7920,7296,10080,8976),
    (16920,8328,17640,9072),
    (20400,9048,23136,11448),
    (9312,10080,10200,10920),
    (10968,11184,11736,11808),
    (14208,11232,15384,12312),
    (2712,12600,4104,13680),
    (7584,13176,8784,14208),
    (10800,13320,12216,14664),
    (22728,13416,24960,15744),
    (4248,15720,5352,16584),
    (10344,15096,12312,16752),
    (20952,15600,21648,16248),
    (20448,18720,21312,19488),
    (23520,20592,25128,22032),
    (8568,24144,9432,25200),
    (16104,23952,18288,26064),
    (21764,24968,22076,25232),
    (14692,26352,15004,26704)
]

# Function to crop the image based on given coordinates
def crop_image(image, crop_rectangle):
    x, y, width, height = crop_rectangle
    height = height - y
    width = width - x
    return image[y:y+height, x:x+width]

# Crop the rectangles from each channel
for i in range(2):  # Assuming there are two channels as per your original question
    # Load the original .tif file for the channel
    channel_image = tiff.imread(f'well2/channel_{i}.tif')
    
    # Crop each rectangle and save it
    for j, rectangle in enumerate(rectangles):
        cropped_image = crop_image(channel_image, rectangle)
        tiff.imwrite(f'well2/crops/channel_{i}_crop_{j}.tif', cropped_image)

# %%
#G

import tifffile as tiff

# Define your rectangles with coordinates (x, y, width, height)
rectangles = [
    (10464,13056,11680,14112),
    (8768,2112,9920,3584),
    (13792,2848,15712,5312),
    (15968,2752,16576,3264),
    (4384,12800,5184,13504),
    (16576,10912,18432,12224),
    (25664,12352,26848,13376),
    (22720,13984,24960,15712),
    (16064,14560,17376,15744),
    (17440,16544,18208,17184),
    (13536,18240,15552,20480),
    (11712,19520,12576,20320),
    (8192,21312,8864,22048),
    (6336,23776,7328,24672),
    (16416,24192,18528,25664),
    (18976,22720,21344,24608)
    
]

# Function to crop the image based on given coordinates
def crop_image(image, crop_rectangle):
    x, y, width, height = crop_rectangle
    height = height - y
    width = width - x
    return image[y:y+height, x:x+width]

# Crop the rectangles from each channel
for i in range(2):  # Assuming there are two channels as per your original question
    # Load the original .tif file for the channel
    channel_image = tiff.imread(f'well4/channel_{i}.tif')
    
    # Crop each rectangle and save it
    for j, rectangle in enumerate(rectangles):
        cropped_image = crop_image(channel_image, rectangle)
        tiff.imwrite(f'well4/crops/channel_{i}_crop_{j}.tif', cropped_image)

# %%
#G

import tifffile as tiff

# Define your rectangles with coordinates (x, y, width, height)
rectangles = [
    (18472,1848,20892,4368),
    (22096,5424,22960,6455),
    (22768,4752,23656,5712),
    (21088,6980,21592,7548),
    (25360,9067,26728,10411),
    (24388,14227,25072,14815),
    (20668,13543,22048,15127),
    (12176,12723,14896,14851),
    (16672,19795,17840,20947),
    (14512,19411,15200,20115),
    (22704,20691,24144,22227),
    (12048,25000,12880,26040),
    (5056,13832,7696,15224),
    (8800,11320,10288,12632),
    (9120,6816,9600,7296),
    (4032,12144,5088,13080),
    (1230,15462,2838,16344)
    
]

# Function to crop the image based on given coordinates
def crop_image(image, crop_rectangle):
    x, y, width, height = crop_rectangle
    height = height - y
    width = width - x
    return image[y:y+height, x:x+width]

# Crop the rectangles from each channel
for i in range(2):  # Assuming there are two channels as per your original question
    # Load the original .tif file for the channel
    channel_image = tiff.imread(f'well6/channel_{i}.tif')
    
    # Crop each rectangle and save it
    for j, rectangle in enumerate(rectangles):
        cropped_image = crop_image(channel_image, rectangle)
        tiff.imwrite(f'well6/crops/channel_{i}_crop_{j}.tif', cropped_image)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob

image_path = glob.glob('/Users/raul/Desktop/96well_mask/well6/crops/channel_0*.tif')
output_path = '/Users/raul/Desktop/96well_mask/well6/mask/'

for i,p in enumerate(image_path ):
    # Load the DAPI image (grayscale)
    dapi_image_path = p
    dapi_image = cv2.imread(dapi_image_path, cv2.IMREAD_GRAYSCALE)

    # Preprocess the image (e.g., Gaussian blur to reduce noise)
    preprocessed_image = cv2.GaussianBlur(dapi_image, (5, 5), 0)

    # Threshold the image to get a binary mask
    # Otsu's method automatically determines an optimal threshold value
    ret, binary_mask = cv2.threshold(preprocessed_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Post-processing to remove small objects (noise)
    # Find contours (similar to labeling)
    contours, hierarchy = cv2.findContours(binary_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Create an empty mask to draw the contours on
    mask = np.zeros_like(dapi_image)

    # Draw the contours on the mask
    cv2.drawContours(mask, contours, -1, (255), thickness=cv2.FILLED)

    # Optional: Filter by contour area to remove small objects
    min_area = 1
    filtered_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]
    mask_filtered = np.zeros_like(dapi_image)
    cv2.drawContours(mask_filtered, filtered_contours, -1, (255), thickness=cv2.FILLED)

    # Save the filtered mask as a .tif image
    filtered_mask_path = output_path + 'mask_'+ p[44:]
    cv2.imwrite(filtered_mask_path, mask_filtered)

    # # Show the original and the mask
    # fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    # ax[0].imshow(dapi_image, cmap='gray')
    # ax[0].set_title('Original DAPI Image')
    # ax[0].axis('off')

    # ax[1].imshow(mask_filtered, cmap='gray')
    # ax[1].set_title('Mask of Nuclei')
    # ax[1].axis('off')

    # plt.show()

# %%
#Use mask on IF

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


# Function to assign colony based on label (this is a dummy function)
def assign_colony(label):
    # Replace this with actual logic to assign a colony
    return "Colony_" + str(label % 5)  # Example logic

# List to keep track of cell information
cells_info = []

image_path = glob.glob('/Users/raul/Desktop/96well_mask/well4/crops/channel_0*.tif')
output_path = '/Users/raul/Desktop/96well_mask/well4/'

for i,p in enumerate(image_path ):

    # Load the DAPI image (grayscale)
    dapi_image_path = p
    dapi_image = cv2.imread(dapi_image_path, cv2.IMREAD_GRAYSCALE)

    # Preprocess the image (e.g., Gaussian blur to reduce noise)
    preprocessed_image = cv2.GaussianBlur(dapi_image, (5, 5), 0)

    # Threshold the image to get a binary mask
    # Otsu's method automatically determines an optimal threshold value
    ret, binary_mask = cv2.threshold(preprocessed_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Find connected components (unique IDs for each nucleus)
    num_labels, labels_im = cv2.connectedComponents(binary_mask)


    # Convert labels_im to 8-bit image
    labels_im_8bit = np.uint8(labels_im)

    # Expand the mask to include some cytoplasm
    # Define the kernel size for dilation. The size of the kernel affects how much the mask will expand.
    kernel_size = 8  # This value can be adjusted depending on how much you want to expand the mask.
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    expanded_masks = cv2.dilate(labels_im_8bit, kernel, iterations=1)


    # Create an RGB image with the red channel set to the mask and the others to black
    red_mask = np.zeros_like(dapi_image)
    red_mask[expanded_masks > 0] = 255  # Set nuclei to red
    red_mask_rgb = np.stack((red_mask, np.zeros_like(red_mask), np.zeros_like(red_mask)), axis=2)

    # Overlay the red mask on the original image
    alpha = 0.2  # Transparency factor for the mask
    overlayed_img = cv2.addWeighted(red_mask_rgb, alpha, cv2.cvtColor(dapi_image*10, cv2.COLOR_GRAY2BGR), 1 - alpha, 0)



    # Visualize the result
    plt.imshow(overlayed_img)
    plt.title('Overlayed Nuclei Mask on Original DAPI Image')
    plt.axis('off')
    # Save the figure
    filtered_mask_path = output_path +'mask_expanded/'+ 'mask_'+ p[44:-3] +'.png'
    plt.savefig(filtered_mask_path, bbox_inches='tight')
    
    # Save the filtered mask as a .tif image
    filtered_mask_path = output_path +'mask_expanded/'+ 'mask_expanded_'+ p[44:]
    cv2.imwrite(filtered_mask_path, expanded_masks)

    # If you no longer need the plot in memory, you can close it with plt.close()
    plt.close()
    
    
    
    # Load channel 2 image (grayscale)
    channel2_image_path = p[:52] + '1'+p[53:]
    print(p)
    print(channel2_image_path )
    print('--------')
    channel2_image = cv2.imread(channel2_image_path, cv2.IMREAD_GRAYSCALE)

    # Iterate over each label to gather cell information from channel 2
    for label in range(1, num_labels):  # start from 1 to exclude the background
        mask = labels_im   == label
        cell_pixels = channel2_image[mask]

        # For simplicity, let's say we take the mean intensity of the cell as its value
        cell_intensity = cell_pixels.mean()
        cell_intensity_med = np.median(cell_pixels)

        # Assign colony to the cell
        colony = assign_colony(label)
        
        # Add the cell information to the list
        cells_info.append({
            'Name': p[:52] + '1'+p[53:],
            'Colony': p[59:-4],
            'Cell': label,
            'Mean_Intensity': cell_intensity,
            'Median_Intensity': cell_intensity_med
        })

# Convert the dictionary into a pandas DataFrame
df_cells = pd.DataFrame(cells_info)

# Save the DataFrame to a CSV file
df_cells.to_csv(output_path+output_path[-6:-1]+'.csv', index=False)  # Set index=False if you don't want to save the index
# Out:
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_9.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_9.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_8.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_8.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_14.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_14.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_15.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_15.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_12.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_12.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_13.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_13.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_11.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_11.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_10.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_10.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_6.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_6.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_7.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_7.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_5.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_5.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_4.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_4.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_0.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_0.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_1.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_1.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_3.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_3.tif
# --------
# /Users/raul/Desktop/96well_mask/well4/crops/channel_0_crop_2.tif
# /Users/raul/Desktop/96well_mask/well4/crops/channel_1_crop_2.tif
# --------

# %%
#Load in dataframe

# %%
wells_names = ['well4']#,'well6']
wells_names = ['well1','well2']
# List of your dataframes
list_of_dataframes = []

for w in wells_names:
    df = pd.read_csv('/Users/raul/Desktop/96well_mask/'+w+'/'+w+'.csv')
    df['WellID'] = w  # or whatever your WellID should be

    list_of_dataframes.append(df)

# Concatenate them
combined_df = pd.concat(list_of_dataframes, ignore_index=True)


# Convert both columns to string if they aren't already
combined_df['WellID'] = combined_df['WellID'].astype(str)
combined_df['Colony'] = combined_df['Colony'].astype(str)

# Create a new ID by combining WellID and Colony
combined_df['NewID'] = combined_df['WellID'] + '_' + combined_df['Colony']

# %%
# combined_df = combined_df[combined_df['NewID'] != 'well4_2']

# %%
# combined_df[combined_df['NewID'] == 'well4_2']
# Out:
#                                                     Name Colony  Cell  \
# 19779  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2     1
# 19780  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2     2
# 19781  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2     3
# 19782  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2     4
# 19783  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2     5
# ...                                                  ...    ...   ...
# 22922  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2  3144
# 22923  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2  3145
# 22924  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2  3146
# 22925  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2  3147
# 22926  /Users/raul/Desktop/96well_mask/well4/crops/ch...      2  3148
#
#        Mean_Intensity  Median_Intensity WellID    NewID
# 19779        8.113636               8.0  well4  well4_2
# 19780        8.597403               8.0  well4  well4_2
# 19781        8.100000               8.0  well4  well4_2
# 19782        8.684848               9.0  well4  well4_2
# 19783        8.243243               8.0  well4  well4_2
# ...               ...               ...    ...      ...
# 22922       15.830409              15.0  well4  well4_2
# 22923       14.082353              14.0  well4  well4_2
# 22924       18.888889              19.0  well4  well4_2
# 22925        8.278481               8.0  well4  well4_2
# 22926        9.451220               9.0  well4  well4_2
#
# [3148 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'df_cells' is the DataFrame containing the cell information with colony assignment
df_cells = combined_df
# Group by 'Colony' to calculate the mean intensity and count the number of cells in each colony
colony_stats = df_cells.groupby('NewID').agg({
    'Mean_Intensity': 'mean',
    'Cell': 'count'  # Counting the number of cells (labels) in each colony
}).reset_index()

# Rename columns for clarity
colony_stats.rename(columns={'Mean_Intensity': 'Average_Mean_Intensity', 'Cell': 'Colony_Size'}, inplace=True)

# Plotting Mean Intensity vs Colony Size
plt.figure(figsize=(10, 6))
plt.scatter(colony_stats['Colony_Size'], colony_stats['Average_Mean_Intensity'], color='blue')

# Annotating each point with the colony name
for i, row in colony_stats.iterrows():
    plt.text(row['Colony_Size'], row['Average_Mean_Intensity'], row['NewID'], fontsize=9)

plt.xlabel('Colony Size (Number of Cells)')
plt.ylabel('Average Mean Intensity')
plt.title('Colony Mean Intensity vs Colony Size')
plt.grid(True)
# Save the figure as a PDF file
plt.savefig('scatterplot_STR_KRT14.pdf', format='pdf', bbox_inches='tight')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df_cells' is the DataFrame containing the cell information with colony assignments

# Compute the colony sizes
colony_sizes = df_cells.groupby('NewID')['Cell'].count().reset_index(name='Colony_Size')

# Merge the colony size back into the original DataFrame
df_cells = df_cells.merge(colony_sizes, on='NewID')

# Sort the DataFrame by colony size in ascending order to determine the plot order
df_cells_sorted = df_cells.sort_values(by='Colony_Size', ascending=True)

# Now, create a new column 'Colony_Order' based on the sorted colony sizes
df_cells_sorted['Colony_Order'] = df_cells_sorted['NewID'].astype('category')
df_cells_sorted['Colony_Order'].cat.set_categories(
    df_cells_sorted['NewID'].unique(), inplace=True, ordered=True
)

# Plotting the boxplots with seaborn
plt.figure(figsize=(12, 8))
ax = sns.boxplot(
    x='Colony_Order', y='Mean_Intensity',
    data=df_cells_sorted, order=df_cells_sorted['Colony_Order'].cat.categories#,
    #showfliers=False
)

# Improve the readability of the plot
plt.xticks(rotation=45, ha='right')  # Rotate the x labels for better visibility
plt.xlabel('Colony')
plt.ylabel('Intensity')
plt.title('Boxplot of Intensities for Each Colony Ordered by Colony Size (Smallest to Largest)')
# plt.ylim(0,30)
plt.tight_layout()  # Adjust layout to fit everything nicely

# Save the figure as a PDF file
plt.savefig('boxplot_STR_KRT14_outliers.pdf', format='pdf', bbox_inches='tight')

plt.show()
# Out:
# /Users/raul/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2747: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)

# %%
1+1
# Out:
# 2

# %%
# KI67 and KRT14

# %%
import nd2reader
import tifffile as tiff

# Path to the .nd2 file
nd2_file_path = '/Volumes/rag_big_2/Raul/20231106_STR_K14_KI67/20231106_151653_664__Plate20231106_STR_KRT14_KI67_Well1_ChannelDAPI,GFP,A647_Seq0000.nd2'

# Load the .nd2 file
nd2 = nd2reader.ND2Reader(nd2_file_path)

# Extract metadata to find out how many channels there are
# This depends on the nd2reader version; if this doesn't work, consult the specific version's documentation
metadata = nd2.metadata

# Get the number of channels
num_channels = len(metadata['channels'])

# Loop through each channel and save the images
for i in range(num_channels):
    # Assuming we are only dealing with a single frame and single z-level
    # Adjust the code here if you have multiple frames or z-levels
    images = nd2.get_frame_2D(c=i)
    
    # Save the images
    tiff.imwrite(f'channel_{i}.tif', images)

# Close the nd2 file
nd2.close()

# %%
#KRT14

import tifffile as tiff
import math

# Define your rectangles with coordinates (x, y, width, height)
rectangles = [
    (10048,9630, 10472, 10046),
    (16208,1568,16856,2256),
    (7336,11249,8363,12321),
    (2736,9737,3792,10657),
    (11496,18729,13256,20265),
    (7976,23720,8984,24720),
    (10728,24440,12200,26264),
    (11648,26400,12560,27232),
    (13592,27040,14824,27712),
    (14712,26184,16168,27528),
    (16648,24840,18712,26968),
    (23728,19110,25472,20446),
    (17648,21942,18888,23102),
    (20728,21710,22808,23494),
    (22152,7310,24544,9374),
]

# Calculate the expansion factor for one side
k = math.sqrt(1.20)

# Decrease x1 and y1 by this factor to keep the aspect ratio and increase area by 10%
rectangles = [(int((x1 - (x2 - x1) * (k - 1))), int((y1 - (y2 - y1) * (k - 1))), x2, y2) for (x1, y1, x2, y2) in rectangles]

# Function to crop the image based on given coordinates
def crop_image(image, crop_rectangle):
    x, y, width, height = crop_rectangle
    height = height - y
    width = width - x
    return image[y:y+height, x:x+width]

# Crop the rectangles from each channel
for i in range(3):  # Assuming there are two channels as per your original question
    # Load the original .tif file for the channel
    channel_image = tiff.imread(f'well1_KI67_KRT14/channel_{i}.tif')
    
    # Crop each rectangle and save it
    for j, rectangle in enumerate(rectangles):
        cropped_image = crop_image(channel_image, rectangle)
        tiff.imwrite(f'well1_KI67_KRT14/crops/channel_{i}_crop_{j}.tif', cropped_image)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob

image_path = glob.glob('/Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0*.tif')
output_path = '/Users/raul/Desktop/96well_mask/well1_KI67_KRT14/mask/'

for i,p in enumerate(image_path ):
#     print(p)
    # Load the DAPI image (grayscale)
    dapi_image_path = p
    dapi_image = cv2.imread(dapi_image_path, cv2.IMREAD_GRAYSCALE)

    # Preprocess the image (e.g., Gaussian blur to reduce noise)
    preprocessed_image = cv2.GaussianBlur(dapi_image, (5, 5), 0)

    # Threshold the image to get a binary mask
    # Otsu's method automatically determines an optimal threshold value
    ret, binary_mask = cv2.threshold(preprocessed_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Post-processing to remove small objects (noise)
    # Find contours (similar to labeling)
    contours, hierarchy = cv2.findContours(binary_mask, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Create an empty mask to draw the contours on
    mask = np.zeros_like(dapi_image)

    # Draw the contours on the mask
    cv2.drawContours(mask, contours, -1, (255), thickness=cv2.FILLED)

    # Optional: Filter by contour area to remove small objects
    min_area = 1
    filtered_contours = [cnt for cnt in contours if cv2.contourArea(cnt) > min_area]
    mask_filtered = np.zeros_like(dapi_image)
    cv2.drawContours(mask_filtered, filtered_contours, -1, (255), thickness=cv2.FILLED)

    # Save the filtered mask as a .tif image
    filtered_mask_path = output_path + 'mask_'+ p[63:]
#     print(filtered_mask_path)
    cv2.imwrite(filtered_mask_path, mask_filtered)

    # # Show the original and the mask
    # fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    # ax[0].imshow(dapi_image, cmap='gray')
    # ax[0].set_title('Original DAPI Image')
    # ax[0].axis('off')

    # ax[1].imshow(mask_filtered, cmap='gray')
    # ax[1].set_title('Mask of Nuclei')
    # ax[1].axis('off')

    # plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Function to assign colony based on label (this is a dummy function)
def assign_colony(label):
    # Replace this with actual logic to assign a colony
    return "Colony_" + str(label % 5)  # Example logic

# List to keep track of cell information
cells_info = []

image_path = glob.glob('/Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0*.tif')
output_path = '/Users/raul/Desktop/96well_mask/well1_KI67_KRT14/'

for i,p in enumerate(image_path ):

    # Load the DAPI image (grayscale)
    dapi_image_path = p
    dapi_image = cv2.imread(dapi_image_path, cv2.IMREAD_GRAYSCALE)

    # Preprocess the image (e.g., Gaussian blur to reduce noise)
    preprocessed_image = cv2.GaussianBlur(dapi_image, (5, 5), 0)

    # Threshold the image to get a binary mask
    # Otsu's method automatically determines an optimal threshold value
    ret, binary_mask = cv2.threshold(preprocessed_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Find connected components (unique IDs for each nucleus)
    num_labels, labels_im = cv2.connectedComponents(binary_mask)


    # Convert labels_im to 8-bit image
    labels_im_8bit = np.uint8(labels_im)

    # Expand the mask to include some cytoplasm
    # Define the kernel size for dilation. The size of the kernel affects how much the mask will expand.
    kernel_size = 8  # This value can be adjusted depending on how much you want to expand the mask.
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    expanded_masks = cv2.dilate(labels_im_8bit, kernel, iterations=1)


    # Create an RGB image with the red channel set to the mask and the others to black
    red_mask = np.zeros_like(dapi_image)
    red_mask[expanded_masks > 0] = 255  # Set nuclei to red
    red_mask_rgb = np.stack((red_mask, np.zeros_like(red_mask), np.zeros_like(red_mask)), axis=2)

    # Overlay the red mask on the original image
    alpha = 0.2  # Transparency factor for the mask
    overlayed_img = cv2.addWeighted(red_mask_rgb, alpha, cv2.cvtColor(dapi_image*10, cv2.COLOR_GRAY2BGR), 1 - alpha, 0)



    # Visualize the result
    plt.imshow(overlayed_img)
    plt.title('Overlayed Nuclei Mask on Original DAPI Image')
    plt.axis('off')
    # Save the figure
    filtered_mask_path = output_path +'mask_expanded/'+ 'mask_'+ p[63:-3] +'.png'
    plt.savefig(filtered_mask_path, bbox_inches='tight')
    
    # Save the filtered mask as a .tif image
    filtered_mask_path = output_path +'mask_expanded/'+ 'mask_expanded_'+ p[63:]
    cv2.imwrite(filtered_mask_path, expanded_masks)

    # If you no longer need the plot in memory, you can close it with plt.close()
    plt.close()
    
    
    
    # Load channel 1 image (grayscale)
    channel1_image_path = p[:63] + '1'+p[64:]
    
    channel2_image_path = p[:63] + '2'+p[64:]
    
    print(p)
    print(channel1_image_path )
    print(channel2_image_path )
    print('--------')
    channel1_image = cv2.imread(channel1_image_path, cv2.IMREAD_GRAYSCALE)
    
    channel2_image = cv2.imread(channel2_image_path, cv2.IMREAD_GRAYSCALE)

    # Iterate over each label to gather cell information from channel 2
    for label in range(1, num_labels):  # start from 1 to exclude the background
        mask = labels_im   == label
        cell_pixels = channel1_image[mask]

        # For simplicity, let's say we take the mean intensity of the cell as its value
        cell_intensity_1 = cell_pixels.mean()
        cell_intensity_med_1 = np.median(cell_pixels)
        
        cell_pixels = channel2_image[mask]

        # For simplicity, let's say we take the mean intensity of the cell as its value
        cell_intensity_2 = cell_pixels.mean()
        cell_intensity_med_2 = np.median(cell_pixels)

        # Assign colony to the cell
        colony = assign_colony(label)
        
        # Add the cell information to the list
        cells_info.append({
            'Name': p[:63] + '1'+p[64:],
            'Colony': p[70:-4],
            'Cell': label,
            'Mean_Intensity_1': cell_intensity_1,
            'Median_Intensity_1': cell_intensity_med_1,
            'Mean_Intensity_2': cell_intensity_2,
            'Median_Intensity_2': cell_intensity_med_2
        })

# Convert the dictionary into a pandas DataFrame
df_cells = pd.DataFrame(cells_info)

# Save the DataFrame to a CSV file
df_cells.to_csv(output_path+output_path[-17:-1]+'.csv', index=False)  # Set index=False if you don't want to save the index
# Out:
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_9.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_9.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_9.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_8.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_8.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_8.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_14.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_14.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_14.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_12.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_12.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_12.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_13.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_13.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_13.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_11.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_11.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_11.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_10.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_10.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_10.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_6.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_6.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_6.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_7.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_7.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_7.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_5.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_5.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_5.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_4.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_4.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_4.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_0.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_0.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_0.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_1.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_1.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_1.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_3.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_3.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_3.tif
# --------
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_0_crop_2.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_1_crop_2.tif
# /Users/raul/Desktop/96well_mask/well1_KI67_KRT14/crops/channel_2_crop_2.tif
# --------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-02c0b8dd31a6> in <module>
#     113
#     114 # Convert the dictionary into a pandas DataFrame
# --> 115 df_cells = pd.DataFrame(cells_info)
#     116
#     117 # Save the DataFrame to a CSV file
#
# NameError: name 'pd' is not defined

# %%
wells_names = ['well1_KI67_KRT14']
# List of your dataframes
list_of_dataframes = []

for w in wells_names:
    df = pd.read_csv('/Users/raul/Desktop/96well_mask/'+w+'/'+w+'.csv')
    df['WellID'] = w  # or whatever your WellID should be

    list_of_dataframes.append(df)

# Concatenate them
combined_df = pd.concat(list_of_dataframes, ignore_index=True)


# Convert both columns to string if they aren't already
combined_df['WellID'] = combined_df['WellID'].astype(str)
combined_df['Colony'] = combined_df['Colony'].astype(str)

# Create a new ID by combining WellID and Colony
combined_df['NewID'] = combined_df['WellID'] + '_' + combined_df['Colony']
combined_df
# Out:
#                                                     Name Colony  Cell  \
# 0      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     1
# 1      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     2
# 2      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     3
# 3      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     4
# 4      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     5
# ...                                                  ...    ...   ...
# 17717  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   271
# 17718  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   272
# 17719  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   273
# 17720  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   274
# 17721  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   275
#
#        Mean_Intensity_1  Median_Intensity_1  Mean_Intensity_2  \
# 0             27.313433                26.0         36.313433
# 1             29.948276                29.5         27.948276
# 2             30.692308                27.0         18.211538
# 3             37.607143                37.0         30.625000
# 4             33.992366                34.0         42.251908
# ...                 ...                 ...               ...
# 17717         16.589286                16.5         19.607143
# 17718         32.837209                32.0         35.395349
# 17719         20.375000                20.0         16.317308
# 17720         29.525641                27.5         19.128205
# 17721         46.265306                45.0         28.102041
#
#        Median_Intensity_2            WellID               NewID
# 0                    36.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 1                    25.5  well1_KI67_KRT14  well1_KI67_KRT14_9
# 2                    17.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 3                    29.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 4                    38.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# ...                   ...               ...                 ...
# 17717                19.5  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17718                35.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17719                16.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17720                19.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17721                27.0  well1_KI67_KRT14  well1_KI67_KRT14_2
#
# [17722 rows x 9 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'df_cells' is the DataFrame containing the cell information with colony assignment
df_cells = combined_df
# Group by 'Colony' to calculate the mean intensity and count the number of cells in each colony
colony_stats = df_cells.groupby('NewID').agg({
    'Mean_Intensity_1': 'mean',
    'Mean_Intensity_2': 'mean',
    'Cell': 'count'  # Counting the number of cells (labels) in each colony
}).reset_index()

# Rename columns for clarity
colony_stats.rename(columns={'Mean_Intensity_1': 'Average_Mean_Intensity_1','Mean_Intensity_2': 'Average_Mean_Intensity_2', 'Cell': 'Colony_Size'}, inplace=True)

# Plotting Mean Intensity vs Colony Size
plt.figure(figsize=(10, 6))
plt.scatter( colony_stats['Colony_Size'], colony_stats['Average_Mean_Intensity_2'], color='blue')

# Annotating each point with the colony name
for i, row in colony_stats.iterrows():
    plt.text(row['Colony_Size'], row['Average_Mean_Intensity_2'], row['NewID'], fontsize=9)

plt.xlabel('Colony Size (Number of Cells)')
plt.ylabel('Average Mean Intensity')
plt.title('Colony Mean Intensity vs Colony Size')
plt.grid(True)
# Save the figure as a PDF file
plt.savefig('scatterplot_STR_KRT14_KI67.pdf', format='pdf', bbox_inches='tight')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df_cells' is the DataFrame containing the cell information with colony assignments

# Compute the colony sizes
colony_sizes = df_cells.groupby('NewID')['Cell'].count().reset_index(name='Colony_Size')

# Merge the colony size back into the original DataFrame
df_cells = df_cells.merge(colony_sizes, on='NewID')

# Sort the DataFrame by colony size in ascending order to determine the plot order
df_cells_sorted = df_cells.sort_values(by='Colony_Size', ascending=True)

# Now, create a new column 'Colony_Order' based on the sorted colony sizes
df_cells_sorted['Colony_Order'] = df_cells_sorted['NewID'].astype('category')
df_cells_sorted['Colony_Order'].cat.set_categories(
    df_cells_sorted['NewID'].unique(), inplace=True, ordered=True
)

# Plotting the boxplots with seaborn
plt.figure(figsize=(12, 8))
ax = sns.boxplot(
    x='Colony_Order', y='Mean_Intensity_1',
    data=df_cells_sorted, order=df_cells_sorted['Colony_Order'].cat.categories#,
    #showfliers=False
)

# Improve the readability of the plot
plt.xticks(rotation=45, ha='right')  # Rotate the x labels for better visibility
plt.xlabel('Colony')
plt.ylabel('Intensity')
plt.title('Boxplot of Intensities for Each Colony Ordered by Colony Size (Smallest to Largest)')
# plt.ylim(0,30)
# plt.tight_layout()  # Adjust layout to fit everything nicely

# Save the figure as a PDF file
plt.savefig('boxplot_STR_KI67.pdf', format='pdf', bbox_inches='tight')

plt.show()
# Out:
# /Users/raul/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2747: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'df_cells' is the DataFrame containing the cell information with colony assignments

# Compute the colony sizes
colony_sizes = df_cells.groupby('NewID')['Cell'].count().reset_index(name='Colony_Size')

# Merge the colony size back into the original DataFrame
df_cells = df_cells.merge(colony_sizes, on='NewID')

# Sort the DataFrame by colony size in ascending order to determine the plot order
df_cells_sorted = df_cells.sort_values(by='Colony_Size', ascending=True)

# Now, create a new column 'Colony_Order' based on the sorted colony sizes
df_cells_sorted['Colony_Order'] = df_cells_sorted['NewID'].astype('category')
df_cells_sorted['Colony_Order'].cat.set_categories(
    df_cells_sorted['NewID'].unique(), inplace=True, ordered=True
)


# Plotting the violin plots with seaborn
plt.figure(figsize=(12, 8))
ax = sns.violinplot(
    x='Colony_Order', y='Mean_Intensity_2',
    data=df_cells_sorted, order=df_cells_sorted['Colony_Order'].cat.categories,
    scale='width',  # This scales the violin width by the number of observations
    inner='point'  # This adds a layer of individual points to the violin plot
)

# Improve the readability of the plot
plt.xticks(rotation=45, ha='right')  # Rotate the x labels for better visibility
plt.xlabel('Colony')
plt.ylabel('Intensity')
plt.title('Violin Plot of Intensities for Each Colony Ordered by Colony Size (Smallest to Largest)')

# Save the figure as a PDF file
plt.savefig('violinplot_STR_KRT14.pdf', format='pdf', bbox_inches='tight')

plt.show()
# Out:
# /Users/raul/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2747: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)

# %%
df_cells
# Out:
#                                                     Name Colony  Cell  \
# 0      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     1
# 1      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     2
# 2      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     3
# 3      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     4
# 4      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     5
# ...                                                  ...    ...   ...
# 17717  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   271
# 17718  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   272
# 17719  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   273
# 17720  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   274
# 17721  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   275
#
#        Mean_Intensity_1  Median_Intensity_1  Mean_Intensity_2  \
# 0             27.313433                26.0         36.313433
# 1             29.948276                29.5         27.948276
# 2             30.692308                27.0         18.211538
# 3             37.607143                37.0         30.625000
# 4             33.992366                34.0         42.251908
# ...                 ...                 ...               ...
# 17717         16.589286                16.5         19.607143
# 17718         32.837209                32.0         35.395349
# 17719         20.375000                20.0         16.317308
# 17720         29.525641                27.5         19.128205
# 17721         46.265306                45.0         28.102041
#
#        Median_Intensity_2            WellID               NewID  \
# 0                    36.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 1                    25.5  well1_KI67_KRT14  well1_KI67_KRT14_9
# 2                    17.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 3                    29.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 4                    38.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# ...                   ...               ...                 ...
# 17717                19.5  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17718                35.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17719                16.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17720                19.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17721                27.0  well1_KI67_KRT14  well1_KI67_KRT14_2
#
#        Colony_Size_x  Colony_Size_y  Colony_Size_x  Colony_Size_y  \
# 0               1390           1390           1390           1390
# 1               1390           1390           1390           1390
# 2               1390           1390           1390           1390
# 3               1390           1390           1390           1390
# 4               1390           1390           1390           1390
# ...              ...            ...            ...            ...
# 17717            275            275            275            275
# 17718            275            275            275            275
# 17719            275            275            275            275
# 17720            275            275            275            275
# 17721            275            275            275            275
#
#        Colony_Size_x  Colony_Size_y  Colony_Size_x  Colony_Size_y  Colony_Size
# 0               1390           1390           1390           1390         1390
# 1               1390           1390           1390           1390         1390
# 2               1390           1390           1390           1390         1390
# 3               1390           1390           1390           1390         1390
# 4               1390           1390           1390           1390         1390
# ...              ...            ...            ...            ...          ...
# 17717            275            275            275            275          275
# 17718            275            275            275            275          275
# 17719            275            275            275            275          275
# 17720            275            275            275            275          275
# 17721            275            275            275            275          275
#
# [17722 rows x 18 columns]

# %%
# Count the number of cells per NewID (colony)
df_cells['Colony_Cell_Count'] = df_cells.groupby('NewID')['NewID'].transform('count')
df_cells
# Out:
#                                                     Name Colony  Cell  \
# 0      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     1
# 1      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     2
# 2      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     3
# 3      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     4
# 4      /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      9     5
# ...                                                  ...    ...   ...
# 17717  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   271
# 17718  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   272
# 17719  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   273
# 17720  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   274
# 17721  /Users/raul/Desktop/96well_mask/well1_KI67_KRT...      2   275
#
#        Mean_Intensity_1  Median_Intensity_1  Mean_Intensity_2  \
# 0             27.313433                26.0         36.313433
# 1             29.948276                29.5         27.948276
# 2             30.692308                27.0         18.211538
# 3             37.607143                37.0         30.625000
# 4             33.992366                34.0         42.251908
# ...                 ...                 ...               ...
# 17717         16.589286                16.5         19.607143
# 17718         32.837209                32.0         35.395349
# 17719         20.375000                20.0         16.317308
# 17720         29.525641                27.5         19.128205
# 17721         46.265306                45.0         28.102041
#
#        Median_Intensity_2            WellID               NewID  \
# 0                    36.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 1                    25.5  well1_KI67_KRT14  well1_KI67_KRT14_9
# 2                    17.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 3                    29.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# 4                    38.0  well1_KI67_KRT14  well1_KI67_KRT14_9
# ...                   ...               ...                 ...
# 17717                19.5  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17718                35.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17719                16.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17720                19.0  well1_KI67_KRT14  well1_KI67_KRT14_2
# 17721                27.0  well1_KI67_KRT14  well1_KI67_KRT14_2
#
#        Colony_Cell_Count
# 0                   1390
# 1                   1390
# 2                   1390
# 3                   1390
# 4                   1390
# ...                  ...
# 17717                275
# 17718                275
# 17719                275
# 17720                275
# 17721                275
#
# [17722 rows x 10 columns]

# %%
# Normalize the colony size for color mapping
norm_colony_size = (df_cells['Colony_Cell_Count'] - df_cells['Colony_Cell_Count'].min()) / (df_cells['Colony_Cell_Count'].max() - df_cells['Colony_Cell_Count'].min())

# Normalize the 'Mean_Intensity' column
norm_M1 = (df_cells['Mean_Intensity_1'] - df_cells['Mean_Intensity_1'].min()) / (df_cells['Mean_Intensity_1'].max() - df_cells['Mean_Intensity_1'].min())
norm_M2 = (df_cells['Mean_Intensity_2'] - df_cells['Mean_Intensity_2'].min()) / (df_cells['Mean_Intensity_2'].max() - df_cells['Mean_Intensity_2'].min())


# Create a scatter plot
plt.figure(figsize=(12, 8))
plt.scatter(
    norm_M1,  # Replace with your actual x-coordinate column
    norm_M2,  # Replace with your actual y-coordinate column
    c=norm_colony_size,  # This will be the color based on the normalized colony size
    cmap='viridis',  # This is a color map, you can choose any you like
    alpha=0.2  # Adjusts the transparency of the points
)

# Create a color bar
plt.colorbar(label='Normalized Colony Size')

# Improve the readability of the plot
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title('Scatter Plot of Cells Colored by Colony Size')

# Show the plot
plt.show()

# %%
# Sort the DataFrame by 'Colony_Size' in descending order so that larger colonies get plotted first
df_cells_sorted = df_cells.sort_values('Colony_Cell_Count', ascending=True)

# Normalize the colony size for color mapping
norm_colony_size = (df_cells_sorted['Colony_Cell_Count'] - df_cells_sorted['Colony_Cell_Count'].min()) / (df_cells_sorted['Colony_Cell_Count'].max() - df_cells_sorted['Colony_Cell_Count'].min())

# Create a scatter plot
plt.figure(figsize=(12, 8))
scatter = plt.scatter(
    df_cells_sorted['Mean_Intensity_1'],  # Replace with your actual x-coordinate column
    df_cells_sorted['Mean_Intensity_2'],  # Replace with your actual y-coordinate column
    c= df_cells_sorted['Colony_Cell_Count'],  # This will be the color based on the normalized colony size
    cmap='rainbow',  # This is a color map, you can choose any you like
    alpha=.7  # Adjusts the transparency of the points
    #edgecolor='w',  # Adds a white edge to each point, if desired for better visibility
)

# Create a color bar
plt.colorbar(scatter, label='Number of cells per colony')

# Improve the readability of the plot
plt.xlabel('KI67 [AU]')
plt.ylabel('KRT14 [AU]')
plt.title('Scatter Plot of Cells Colored by Colony Size')

# Save the figure as a PDF file
plt.savefig('scatterplot.pdf', format='pdf', bbox_inches='tight')

# Show the plot
plt.show()

# %%
median_colony,smallest_colony ,largest_colony
# Out:
# (3484.0, 11, 5399)

# %%
# Calculate the sizes of each colony
colony_sizes = df_cells.groupby('NewID').size().reset_index(name='Colony_Cell_Count')

# Find the top three and bottom three colonies
top_three_colonies = colony_sizes.nlargest(1, 'Colony_Cell_Count')['NewID']
bottom_three_colonies = colony_sizes.nsmallest(3, 'Colony_Cell_Count')['NewID']

# Filter the DataFrame to include only cells from these six colonies
top_bottom_cells = df_cells[df_cells['NewID'].isin(top_three_colonies) | df_cells['NewID'].isin(bottom_three_colonies)]

# Plot the cells from the top and bottom three colonies
plt.figure(figsize=(12, 8))

# Plot top three colonies
for colony in top_three_colonies:
    colony_cells = top_bottom_cells[top_bottom_cells['NewID'] == colony]
    plt.scatter(
        colony_cells['Mean_Intensity_1'],  # Replace with your actual x-coordinate column
        colony_cells['Mean_Intensity_2'],  # Replace with your actual y-coordinate column
        label=f'Colony {colony} (Top 3)',
        alpha=0.5,
        c='darkblue'
    )

# Plot bottom three colonies
for colony in bottom_three_colonies:
    colony_cells = top_bottom_cells[top_bottom_cells['NewID'] == colony]
    plt.scatter(
        colony_cells['Mean_Intensity_1'],  # Replace with your actual x-coordinate column
        colony_cells['Mean_Intensity_2'],  # Replace with your actual y-coordinate column
        label=f'Colony {colony} (Bottom 3)',
        alpha=1,
        c='green'
    )

# Improve the readability of the plot
plt.xlabel('KI67 [AU]')
plt.ylabel('KRT14 [AU]')
plt.title('Scatter Plot of Cells from Top and Bottom 3 Colonies')
plt.legend(['Largest colony','Smallest 3 colonies'])


# Save the figure as a PDF file
plt.savefig('scatterplot_top1_bot3.pdf', format='pdf', bbox_inches='tight')

plt.show()
